# %% [markdown]
# <a href="https://colab.research.google.com/github/SarahSouzaPontes/classificacaoderiscoEME/blob/main/Classifica%C3%A7%C3%A3oDeRisco.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Passo 1: Configurar o ambiente no Google Colab
import pandas as pd
from IPython.display import display, HTML

# Opções para a primeira coluna
opcoes_1A = [
    "PARADA CÁRDIORESPIRATÓRIA (PCR)", "QUEIMADURAS", "TRAUMA DE CRÂNIO", "QUEIXAS ABDOMINAIS", "TRAUMA GERAL",
    "MORDEDURA DE ANIMAL / ACIDENTE COM ANIMAL PEÇONHENTO", "INTOXICAÇÃO AGUDA / ENVENENAMENTO", "DOR TORÁCICA",
    "SANGRAMENTOS", "QUEIXAS URINÁRIAS", "DOR CERVICAL/ DORSAL/ LOMBAR OU EXTREMIDADES", "FERIDAS E ABSCESSOS",
    "CRISE CONVULSIVA/ ALTERAÇÕES NEUROLÓGICAS", "QUEIXAS RESPIRATÓRIAS", "DOR DE CABEÇA", "ALTERAÇÕES GLICÊMICAS",
    "PRESSÃO ALTA", "QUEIXAS OCULARES", "AFECÇÕES CUTÂNEAS/ ANAFILAXIA", "ALTERAÇÕES DE TEMPERATURA",
    "EDEMA/ ICTERÍCIA/ FRAQUEZA/ CÂIMBRA", "DOR DE OUVIDO E GARGANTA", "SITUAÇÕES DE CRISES PSÍQUICAS / ABSTINÊNCIA DE ÁLCOOL E OUTRAS DROGAS",
    "SITUAÇÕES DE BAIXA COMPLEXIDADE"
]

# Opções para a segunda coluna
opcoes_1B = [
    "PARADA CÁRDIORESPIRATÓRIA (PCR)", "DESEQUILÍBRIO HEMODINÂMICO", "ALTERAÇÃO DO NÍVEL DE CONSCIÊNCIA AFOGAMENTO",
     "QUEIXAS RESPIRATÓRIAS", "ALTERAÇÕES DA TEMPERATURA", "DOR DE OUVIDO E GARGANTA",
    "FERIDAS E ABSCESSOS", "SINAIS DE DESIDRATAÇÃO/VÔMITOS", "DEJEÇÕES DIARREICAS", "QUEIXAS ABDOMINAIS",
    "TRAUMA DE CRÂNIO", "TRAUMA GERAL", "QUEIMADURAS", "MORDEDURA DE ANIMAL / ACIDENTE COM ANIMAL PEÇONHENTO",
    "INTOXICAÇÃO AGUDA/ ENVENENAMENTO", "CRIANÇAS MENORES DE 02 MESES"
]

# Preencher com valores vazios para igualar o número de elementos até 24A
max_len = 24
opcoes_1A += [""] * (max_len - len(opcoes_1A))
opcoes_1B += [""] * (max_len - len(opcoes_1B))

# Criar um DataFrame com as duas colunas
df = pd.DataFrame({
    '1A': [f"{i+1}A: {opcao}" for i, opcao in enumerate(opcoes_1A)],
    '1B': [f"{i+1}B: {opcao}" for i, opcao in enumerate(opcoes_1B)]
})

# Exibir a tabela
display(HTML(df.to_html(index=False)))

# Solicitar input do usuário
descritivo = input("\nDigite a opção desejada (ex: 1A, 2B, etc.): ")


#___________________________________________PCR


if descritivo == "1A: PARADA CÁRDIORESPIRATÓRIA (PCR)":

   # Perguntas sobre os sintomas
    sintomas = [
        "AUSÊNCIA DE PULSO EM GRANDES ARTÉRIAS",
        "AUSÊNCIA DE MOVIMENTOS RESPIRATÓRIOS",
        "CIANOSE",
        "LETARGIA OU INCONSCIÊNCIA"
    ]

    # Inicializar variável para controlar se todas as respostas foram 'sim'
    todas_sim = True

    # Perguntar sobre cada sintoma e verificar as respostas
    for sintoma in sintomas:
        resposta = input(f"{sintoma}? (sim/não): ").strip().lower()
        if resposta != "sim":
            todas_sim = False

    # Se todas as respostas forem 'sim', imprimir classificação
    if todas_sim:
        print("\nClassificação de Risco: COR VERMELHA")
    else:
        print("\nClassificação não definida")

#________________________________________________QUEIMADURA_______________________


if descritivo == "2A: QUEIMADURAS":

    # Perguntas sobre os sintomas iniciais
    sintomas_iniciais = [
        "SINAIS VITAIS ALTERADOS COM SINTOMAS:",
        "FC ≤50 ou ≥120 bpm",
        "PAS ≤90 ou ≥ 220 / PAD ≤80 ou ≥130 mmHg",
        "TEMP AXILAR ≤35 ou ≥40º C",
        "FR ≤10 ou ≥25 ipm",
        "SPO2 ≤92%",
        "ASSOCIADAS A POLITRAUMA",
        "PRESENÇA DE FRATURA ÓSSEA EM QUALQUER LOCALIZAÇÃO",
        "PACIENTE PORTADOR DE DOENÇA CRÔNICA",
        "ESCARRO CARBONATO, ESTRIDOR LARÍNGEO OU FALA ENTRECORTADA",
        "INCÊNDIO EM LOCAL CONFINADO/ LESÃO INALATÓRIA",
        "QUEIMADURAS POR CORRENTE ELÉTRICA (INCLUSIVE RAIO)",
        "QUEIMADURAS CIRCUNFERENCIAIS",
        "QUEIMADURAS DE 3º GRAU ≥10% DE SCQ",
        "QUEIMADURAS DE 3º GRAU EM MÃOS OU PÉS OU FACE OU PESCOÇO OU AXILA",
        "QUEIMADURAS DE 2º GRAU COM SCQ ≥20%",
        "QUEIMADURAS DE 2º OU 3º GRAU EM PERÍNEO"
    ]

    # Verificar se todos os sintomas iniciais são "sim"
    todas_sim_iniciais = True
    for sintoma in sintomas_iniciais:
        resposta = input(f"{sintoma}? (sim/não): ").strip().lower()
        if resposta != "sim":
            todas_sim_iniciais = False
            break

    # Determinar a classificação com base nas respostas iniciais
    if todas_sim_iniciais:
        print("\nClassificação de Risco: COR VERMELHA")
    else:
        # Perguntas sobre os sintomas de classificação AMARELA
        sintomas_amarela = [
            "SINAIS VITAIS NORMAIS",
            "QUEIMADURAS DE 2º GRAU COM SCQ ENTRE 10% e 20 %",
            "QUALQUER QUEIMADURA DE 2º GRAU EM MÃOS/ PÉS/ FACE/ PESCOÇO OU ARTICULAÇÕES",
            "QUEIMADURAS QUE NÃO ENVOLVAM MÃOS/ PÉS/ FACE/ PERÍNEO DE 3º GRAU COM ATÉ 10% SCQ"
        ]

        todas_sim_amarela = True
        for sintoma in sintomas_amarela:
            resposta = input(f"{sintoma}? (sim/não): ").strip().lower()
            if resposta != "sim":
                todas_sim_amarela = False
                break

        if todas_sim_amarela:
            print("\nClassificação de Risco: COR AMARELA")
        else:
            # Perguntas sobre os sintomas de classificação VERDE
            sintomas_verde = [
                "SINAIS VITAIS NORMAIS",
                "QUEIMADURAS DE 1º GRAU EM QUALQUER EXTENSÃO",
                "QUEIMADURAS DE 2º GRAU COM SCQ ≤10%"
            ]

            todas_sim_verde = True
            for sintoma in sintomas_verde:
                resposta = input(f"{sintoma}? (sim/não): ").strip().lower()
                if resposta != "sim":
                    todas_sim_verde = False
                    break

            if todas_sim_verde:
                print("\nClassificação de Risco: COR VERDE")
            else:
                # Última pergunta para classificação AZUL
                pergunta_azul = input("TROCA DE CURATIVOS? (sim/não): ").strip().lower()
                if pergunta_azul == "sim":
                    print("\nClassificação de Risco: COR AZUL")
                else:
                    print("\nClassificação não definida")

#______________________________________________________________________


if descritivo == "3A: TRAUMA DE CRÂNIO":
    print("\nVocê escolheu TRAUMA DE CRÂNIO.")

    # Perguntas sobre os sintomas iniciais
    sintomas_iniciais = [
        "SINAIS VITAIS ALTERADOS COM SINTOMAS:",
        "FC ≤50 ou ≥120 bpm",
        "PAS ≤90 ou ≥ 220 / PAD ≤80 ou ≥130 mmHg",
        "TEMP AXILAR ≤35 ou ≥40º C",
        "FR ≤10 ou ≥25 ipm",
        "SPO2 ≤92%",
        "CEFALÉIA OU CERVICALGIA INTENSA (8-10/10) ASSOCIADA A PELO MENOS 1 ALTERAÇÃO DE SSVV DESCRITA ACIMA",
        "FERIMENTO PERFURANTE/ AFUNDAMENTO DE CRÂNIO/ EXPOSIÇÃO DE MASSA ENCEFÁLICA OU LÍQUOR CÉFALORRAQUIDIANO",
        "INCONSCIENTE/ GLASGOW (8/9-12)",
        "AGITAÇÃO PSICOMOTORA",
        "APRESENTANDO NÁUSEAS /VÔMITOS",
        "OTORRAGIA / RINORRÉIARRAGIA OU HEMATOMA PERIORBITAL",
        "FRATURA DE CRÂNIO COM PERDA DE LÍQUOR/ SANGUE OU MASSA ENCEFÁLICA",
        "HEMATOMA RETROAURICULAR (SINAL DE BATLLE)",
        "PRESENÇA DE CRISE CONVULSIVA"
    ]

    # Verificar se todos os sintomas iniciais são "sim"
    todas_sim_iniciais = True
    for sintoma in sintomas_iniciais:
        resposta = input(f"{sintoma}? (sim/não): ").strip().lower()
        if resposta != "sim":
            todas_sim_iniciais = False
            break

    # Determinar a classificação com base nas respostas iniciais
    if todas_sim_iniciais:
        print("\nClassificação de Risco: COR VERMELHA")
    else:
        # Perguntas sobre os sintomas de classificação AMARELA
        sintomas_amarela = [
            "CEFALÉIA MODERADA SEM CERVICALGIA (4-7/10)",
            "FERIMENTO COM HEMORRAGIA CONTROLÁVEL",
            "HISTÓRIA DE INCONSCIÊNCIA",
            "NÍVEL DE CONSCIÊNCIA PRESERVADO - GLASGOW (14-15)"
        ]

        todas_sim_amarela = True
        for sintoma in sintomas_amarela:
            resposta = input(f"{sintoma}? (sim/não): ").strip().lower()
            if resposta != "sim":
                todas_sim_amarela = False
                break

        if todas_sim_amarela:
            print("\nClassificação de Risco: COR AMARELA")
        else:
            # Perguntas sobre os sintomas de classificação VERDE
            sintomas_verde = [
                "SINAIS VITAIS NORMAIS",
                "NÍVEL DE CONSCIÊNCIA PRESERVADO - GLASGOW (15)",
                "CEFALÉIA LEVE (1-3/10)",
                "CONTUSÕES E ESCORIAÇÕES",
                "OCORRÊNCIA HÁ MAIS DE 06 h",
                "TRAUMA DE BAIXO IMPACTO"
            ]

            todas_sim_verde = True
            for sintoma in sintomas_verde:
                resposta = input(f"{sintoma}? (sim/não): ").strip().lower()
                if resposta != "sim":
                    todas_sim_verde = False
                    break

            if todas_sim_verde:
                print("\nClassificação de Risco: COR VERDE")
            else:
                print("\nClassificação não definida")


#___________________________________________________________________________
if descritivo == "4A: QUEIXAS ABDOMINAIS":
    print("\nVocê escolheu QUEIXAS ABDOMINAIS.")

    # Perguntas sobre os sintomas iniciais
    sintomas_iniciais = [
        "SINAIS VITAIS ALTERADOS ASSOCIADOS A 01 OU MAIS SINTOMAS:",
        "FC ≤50 ou ≥120 bpm",
        "PAS ≤90 ou ≥ 220 / PAD ≤80 ou ≥130 mmHg",
        "TEMP AXILAR ≤35 ou ≥40º C",
        "FR ≤10 ou ≥25 ipm",
        "SPO2 ≤92%",
        "DOR INTENSA GENERALIZADA (8-10/10) / AUMENTA DE INTENSIDADE À PALPAÇÃO",
        "DOR INTENSA LOCALIZADA E BEM DEFINIDA (8-10/10) / AUMENTA DE INTENSIDADE À PALPAÇÃO",
        "PRESENÇA DE RIGIDEZ DO ABDOME",
        "DOR AGUDA INTENSA NA SUSPEITA DE GRAVIDEZ, ASSOCIADO A NÁUSEAS E/OU VÔMITOS, SUDORESE E/OU SANGRAMENTO GENITAL",
        "PRESENÇA DE VÔMITO FECALÓIDE",
        "DOR OU INSTABILIDADE PÉLVICA",
        "FERIMENTOS COM SANGRAMENTO NÃO COMPRESSÍVEL/PERFURAÇÃO POR ARMA BRANCA OU PAF",
        "PALIDEZ, SUDORESE E/OU TREMORES",
        "APRESENTANDO VÔMITOS INCOERCÍVEIS, MAIS DE 10 EPISÓDIOS DE DIARREIA COM SINAIS DE DESIDRATAÇÃO"
    ]

    # Verificar se todos os sintomas iniciais são "sim"
    todas_sim_iniciais = True
    for sintoma in sintomas_iniciais:
        resposta = input(f"{sintoma}? (sim/não): ").strip().lower()
        if resposta != "sim":
            todas_sim_iniciais = False
            break

    # Determinar a classificação com base nas respostas iniciais
    if todas_sim_iniciais:
        print("\nClassificação de Risco: COR VERMELHA")
    else:
        # Perguntas sobre os sintomas de classificação AMARELA
        sintomas_amarela = [
            "DOR MODERADA (4-7/10) COM ALTERAÇÃO DE PELO MENOS 01 SSVV",
            "DOR IRRADIA PARA O OMBRO, PESCOÇO, BRAÇOS OU MANDÍBULA",
            "PRESENÇA DE TEMP AXILAR ≥ 38,5º C",
            "HISTÓRIA AGUDA DE VÔMITO COM SANGUE",
            "ABDOME ASCÍTICO ACOMPANHADO DE FEBRE OU DISPNÉIA",
            "APRESENTA FEZES DE ASPECTO ENEGRECIDAS OU GROSELHA",
            "VÔMITOS PERSISTENTES COM SINAIS DE DESIDRATAÇÃO"
        ]

        todas_sim_amarela = True
        for sintoma in sintomas_amarela:
            resposta = input(f"{sintoma}? (sim/não): ").strip().lower()
            if resposta != "sim":
                todas_sim_amarela = False
                break

        if todas_sim_amarela:
            print("\nClassificação de Risco: COR AMARELA")
        else:
            # Perguntas sobre os sintomas de classificação VERDE
            sintomas_verde = [
                "SINAIS VITAIS NORMAIS",
                "DOR LEVE (1-3/10) GENERALIZADA OU LOCALIZADA",
                "VÔMITOS ESPARÇOS",
                "TEMP AXILAR ≤ 38,5ºC"
            ]

            todas_sim_verde = True
            for sintoma in sintomas_verde:
                resposta = input(f"{sintoma}? (sim/não): ").strip().lower()
                if resposta != "sim":
                    todas_sim_verde = False
                    break

            if todas_sim_verde:
                print("\nClassificação de Risco: COR VERDE")
            else:
                # Última pergunta para classificação AZUL
                pergunta_azul = input("OBSTIPAÇÃO INTESTINAL? (sim/não): ").strip().lower()
                if pergunta_azul == "sim":
                    print("\nClassificação de Risco: COR AZUL")
                else:
                    print("\nClassificação não definida")



#_________________________________________________________________
if descritivo == "5A: TRAUMA GERAL":
    print("\nVocê escolheu TRAUMA GERAL.")

    # Perguntas sobre os sintomas iniciais
    sintomas_iniciais = [
        "DADOS VITAIS ALTERADOS COM SINTOMAS:",
        "FC ≤50 ou ≥120 bpm",
        "PAS ≤90 ou ≥ 220 / PAD ≤80 ou ≥130 mmHg",
        "TEMP AXILAR ≤35 ou ≥40º C",
        "FR ≤10 ou ≥25 ipm",
        "SPO2 ≤92%",
        "AMPUTAÇÃO E/OU AVULSÃO (EXCETO DENTÁRIA)",
        "DOR INTENSA (8-10/10) ASSOCIADA A PELO MENOS 01 ALTERAÇÃO DE SSVV",
        "INSTABILIDADE PÉLVICA",
        "PRESENÇA DE RIGIDEZ DO ABDOME",
        "FERIMENTO EXTENSO COM SANGRAMENTO NÃO COMPRESSÍVEL",
        "FRATURAS EXPOSTAS (TIPO II, III-A, III-B, III-C Classificação de Gustillo)",
        "PERDA DE CONSCIÊNCIA",
        "SINAIS DE CHOQUE (HIPOTENSÃO, TAQUICARDIA, PALIDEZ, SUDORESE, TREMORES)",
        "TRAUMA TORÁCICO OU ABDOMINAL COM PERFURAÇÃO POR ARMA BRANCA OU PAF"
    ]

    # Verificar se todos os sintomas iniciais são "sim"
    todas_sim_iniciais = True
    for sintoma in sintomas_iniciais:
        resposta = input(f"{sintoma}? (sim/não): ").strip().lower()
        if resposta != "sim":
            todas_sim_iniciais = False
            break

    # Determinar a classificação com base nas respostas iniciais
    if todas_sim_iniciais:
        print("\nClassificação de Risco: COR VERMELHA")
    else:
        # Perguntas sobre os sintomas de classificação AMARELA
        sintomas_amarela = [
            "DOR MODERADA (4-7/10) ASSOCIADA A PELO MENOS 1 ALTERAÇÃO DE SSVV",
            "FERIMENTOS MENORES COM/SEM SANGRAMENTO ATIVO",
            "FRATURA EXPOSTA (TIPO I Classificação de Gustillo)",
            "FRATURA OU LUXAÇÃO COM DEFORMIDADE",
            "PRESENÇA DE TATUAGEM TRAUMÁTICA",
            "TRAUMA TORÁCICO SEM DISPNÉIA"
        ]

        todas_sim_amarela = True
        for sintoma in sintomas_amarela:
            resposta = input(f"{sintoma}? (sim/não): ").strip().lower()
            if resposta != "sim":
                todas_sim_amarela = False
                break

        if todas_sim_amarela:
            print("\nClassificação de Risco: COR AMARELA")
        else:
            # Perguntas sobre os sintomas de classificação VERDE
            sintomas_verde = [
                "SINAIS VITAIS NORMAIS",
                "CONTUSÕES, ESCORIAÇÕES OU TORÇÕES COM EDEMA LOCAL",
                "DOR LEVE (1-3/10)",
                "EVENTO (TRAUMA) HÁ MAIS DE 06 h",
                "FRATURA DENTAL/AVULSÃO DENTÁRIA"
            ]

            todas_sim_verde = True
            for sintoma in sintomas_verde:
                resposta = input(f"{sintoma}? (sim/não): ").strip().lower()
                if resposta != "sim":
                    todas_sim_verde = False
                    break

            if todas_sim_verde:
                print("\nClassificação de Risco: COR VERDE")
            else:
                # Última pergunta para classificação AZUL
                pergunta_azul = input("FERIMENTOS QUE NÃO REQUEREM INTERVENÇÕES? (sim/não): ").strip().lower()
                if pergunta_azul == "sim":
                    print("\nClassificação de Risco: COR AZUL")
                else:
                    print("\nClassificação não definida")



#_______________________________________________________________________________


if descritivo == "6A: MORDEDURA DE ANIMAL / ACIDENTE COM ANIMAL PEÇONHENTO":
    print("\nVocê escolheu MORDEDURA DE ANIMAL / ACIDENTE COM ANIMAL PEÇONHENTO.")

    # Perguntas sobre os sintomas iniciais
    sintomas_iniciais = [
        "SINAIS VITAIS ALTERADOS COM SINTOMAS:",
        "FC ≤50 ou ≥120 bpm",
        "PAS ≤90 ou ≥ 220 / PAD ≤80 ou ≥130 mmHg",
        "TEMP AXILAR ≤35 ou ≥40º C",
        "FR ≤10 ou ≥25 ipm",
        "SPO2 ≤92%",
        "DOR INTENSA NO LOCAL DA PICADA ASSOCIADA A PELO MENOS 01 ALTERAÇÃO DE SSVV",
        "FERIMENTOS PROFUNDOS, MÚLTIPLOS OU EXTENSOS",
        "SIALORREIA/PARALISIA FACIAL",
        "MIALGIA GENERALIZADA E/OU VISÃO TURVA",
        "HEMORRAGIA ATIVA NÃO COMPRESSÍVEL",
        "CONVULSÃO/ AGITAÇÃO/ DELÍRIO/COMA",
        "ESTRIDOR LARÍNGEO E/OU FALA ENTRECORTADA"
    ]

    # Verificar se todos os sintomas iniciais são "sim"
    todas_sim_iniciais = True
    for sintoma in sintomas_iniciais:
        resposta = input(f"{sintoma}? (sim/não): ").strip().lower()
        if resposta != "sim":
            todas_sim_iniciais = False
            break

    # Determinar a classificação com base nas respostas iniciais
    if todas_sim_iniciais:
        print("\nClassificação de Risco: COR VERMELHA")
    else:
        # Perguntas sobre os sintomas de classificação AMARELA
        sintomas_amarela = [
            "DOR MODERADA COM EDEMA / HIPEREMIA NO LOCAL",
            "ERITEMA NO LOCAL DA LESÃO",
            "MORDEDURA/ARRANHADURA EM FACE, MÃOS E PÉS (HUMANA OU ANIMAL DESCONHECIDO)",
            "LAMBEDURA DE MUCOSAS POR ANIMAL DESCONHECIDO",
            "CONTATO COM ANIMAL ALERGÊNICO (ABELHA, ÁGUA VIVA)",
            "NÁUSEAS, VÔMITOS OU DIARRÉIA"
        ]

        todas_sim_amarela = True
        for sintoma in sintomas_amarela:
            resposta = input(f"{sintoma}? (sim/não): ").strip().lower()
            if resposta != "sim":
                todas_sim_amarela = False
                break

        if todas_sim_amarela:
            print("\nClassificação de Risco: COR AMARELA")
        else:
            # Perguntas sobre os sintomas de classificação VERDE
            sintomas_verde = [
                "DOR E PARESETESIA NO LOCAL",
                "PROVÁVEL CONTATO COM ANIMAL ALERGÊNICO",
                "FERIMENTOS SUPERFICIAIS SEM SANGRAMENTOS OU HEMATOMAS"
            ]

            todas_sim_verde = True
            for sintoma in sintomas_verde:
                resposta = input(f"{sintoma}? (sim/não): ").strip().lower()
                if resposta != "sim":
                    todas_sim_verde = False
                    break

            if todas_sim_verde:
                print("\nClassificação de Risco: COR VERDE")
            else:
                # Última pergunta para classificação AZUL
                pergunta_azul = input("MORDEDURA/ ARRANHADURA DE PEQUENA EXTENSÃO POR ANIMAL DOMÉSTICO DOMICILIADO? (sim/não): ").strip().lower()
                if pergunta_azul == "sim":
                    print("\nClassificação de Risco: COR AZUL")
                else:
                    print("\nClassificação não definida")




#__________________________________________________________________________
if descritivo == "7A: INTOXICAÇÃO AGUDA / ENVENENAMENTO":
    print("\nVocê escolheu INTOXICAÇÃO AGUDA / ENVENENAMENTO.")

    # Perguntas sobre os sintomas iniciais
    sintomas_iniciais = [
        "SINAIS VITAIS ALTERADOS COM SINTOMAS:",
        "FC ≤50 ou ≥120 bpm",
        "PAS ≤90 ou ≥ 220 / PAD ≤80 ou ≥130 mmHg",
        "TEMP AXILAR ≤35 ou ≥40º C",
        "FR ≤10 ou ≥25 ipm",
        "SPO2 ≤92%",
        "INGESTÃO DE SUBSTÂNCIAS QUÍMICAS IDENTIFICADAS: SODA CÁUSTICA, ÁGUA SANITÁRIA, CHUMBINHO, COMPRIMIDOS, COM OU SEM PRODUÇÃO DE SINTOMAS",
        "COM ESTRIDOR LARÍNGEO OU FALA ENTRECORTADA",
        "CONVULSÃO/AGITAÇÃO/COMA",
        "HISTÓRIA DE TRAUMA CRANIANO (TCE)",
        "INGESTÃO HÁ MENOS DE 6H COM OU SEM SINTOMAS",
        "SIALORREIA/ RELAXAMENTO ESFINCTERIANO ASSOCIADA A PELO MENOS 01 ALTERAÇÃO DE SSVV",
        "RELATO DE INALAÇÃO COM DISPNEIA E/OU OUTROS SINTOMAS ASSOCIADOS",
        "TIPO E QUANTIDADE DE DROGAS DESCONHECIDO ASSOCIADA A PELO MENOS 01 ALTERAÇÃO DE SSVV"
    ]

    # Verificar se todos os sintomas iniciais são "sim"
    todas_sim_iniciais = True
    for sintoma in sintomas_iniciais:
        resposta = input(f"{sintoma}? (sim/não): ").strip().lower()
        if resposta != "sim":
            todas_sim_iniciais = False
            break

    # Determinar a classificação com base nas respostas iniciais
    if todas_sim_iniciais:
        print("\nClassificação de Risco: COR VERMELHA")
    else:
        # Perguntas sobre os sintomas de classificação AMARELA
        sintomas_amarela = [
            "CÂIMBRAS/FRAQUEZA MUSCULAR",
            "CEFALEIA/TONTURAS",
            "NÁUSEAS/VÔMITOS",
            "PRURIDO OU IRRITAÇÃO INTENSA APÓS CONTATO DÉRMICO",
            "RELATO DE INGESTÃO HÁ MAIS DE 6h ASSINTOMÁTICO"
        ]

        todas_sim_amarela = True
        for sintoma in sintomas_amarela:
            resposta = input(f"{sintoma}? (sim/não): ").strip().lower()
            if resposta != "sim":
                todas_sim_amarela = False
                break

        if todas_sim_amarela:
            print("\nClassificação de Risco: COR AMARELA")
        else:
            # Perguntas sobre os sintomas de classificação VERDE
            sintomas_verde = [
                "NÍVEL DE CONSCIÊNCIA PRESERVADO",
                "ALTERAÇÕES DÉRMICAS APENAS LOCAIS"
            ]

            todas_sim_verde = True
            for sintoma in sintomas_verde:
                resposta = input(f"{sintoma}? (sim/não): ").strip().lower()
                if resposta != "sim":
                    todas_sim_verde = False
                    break

            if todas_sim_verde:
                print("\nClassificação de Risco: COR VERDE")
            else:
                # Última pergunta para classificação AZUL
                pergunta_azul = input("CONTATO COM SUBSTÂNCIA QUÍMICA > 4 h, ASSINTOMÁTICO? (sim/não): ").strip().lower()
                if pergunta_azul == "sim":
                    print("\nClassificação de Risco: COR AZUL")
                else:
                    print("\nClassificação não definida")





#______________________________________________________________________________

if descritivo == "8A: DOR TORÁCICA":
    print("\nVocê escolheu DOR TORÁCICA.")

    # Perguntas sobre os sintomas iniciais
    sintomas_iniciais = [
        "SINAIS VITAIS ALTERADOS COM SINTOMAS:",
        "FC ≤50 ou ≥120 bpm",
        "PAS ≤90 ou ≥ 220 / PAD ≤80 ou ≥130 mmHg",
        "TEMP AXILAR ≤35 ou ≥40º C",
        "FR ≤10 ou ≥25 ipm",
        "SPO2 ≤92%",
        "DOR INTENSA EM PESO, OPRESSÃO, QUEIMAÇÃO, DESCONFORTO/ ANSIEDADE",
        "IRRADIA: PESCOÇO, OMBROS, MANDÍBULA, BRAÇO, DORSO OU EPIGÁSTRIO",
        "NAUSEAS / VÔMITOS/ DISPNÉIA / SUDORESE FRIA / PALIDEZ"
    ]

    # Verificar se todos os sintomas iniciais são "sim"
    todas_sim_iniciais = True
    for sintoma in sintomas_iniciais:
        resposta = input(f"{sintoma}? (sim/não): ").strip().lower()
        if resposta != "sim":
            todas_sim_iniciais = False
            break

    # Determinar a classificação com base nas respostas iniciais
    if todas_sim_iniciais:
        print("\nClassificação de Risco: COR VERMELHA")
    else:
        # Perguntas sobre os sintomas de classificação AMARELA
        sintomas_amarela = [
            "DOR MODERADA (3-7/10) QUE PIORA COM RESPIRAÇÃO PROFUNDA / TOSSE / DISPNEIA / PALPAÇÃO",
            "CARDIOPATIA PRÉVIA E/OU DIABETES E/OU HIPERTENSÃO"
        ]

        todas_sim_amarela = True
        for sintoma in sintomas_amarela:
            resposta = input(f"{sintoma}? (sim/não): ").strip().lower()
            if resposta != "sim":
                todas_sim_amarela = False
                break

        if todas_sim_amarela:
            print("\nClassificação de Risco: COR AMARELA")
        else:
            # Perguntas sobre os sintomas de classificação VERDE
            sintomas_verde = [
                "DOR À PALPAÇÃO DE CARACTERÍSTICA MUSCULAR",
                "DOR AGUDA LEVE SEM HISTÓRIA DE CARDIOPATIA"
            ]

            todas_sim_verde = True
            for sintoma in sintomas_verde:
                resposta = input(f"{sintoma}? (sim/não): ").strip().lower()
                if resposta != "sim":
                    todas_sim_verde = False
                    break

            if todas_sim_verde:
                print("\nClassificação de Risco: COR VERDE")
            else:
                # Última pergunta para classificação AZUL
                pergunta_azul = input("DOR TORÁCICA HÁ MAIS DE 07 DIAS? (sim/não): ").strip().lower()
                if pergunta_azul == "sim":
                    print("\nClassificação de Risco: COR AZUL")
                else:
                    print("\nClassificação não definida")


#______________________________________________________________________________________________
if descritivo == "9A: SANGRAMENTOS":
    print("\nVocê escolheu SANGRAMENTOS.")

    # Perguntas sobre os sintomas iniciais
    sintomas_iniciais = [
        "SINAIS VITAIS ALTERADOS COM SINTOMAS:",
        "FC ≤50 ou ≥120 bpm",
        "PAS ≤90 ou ≥ 220 / PAD ≤80 ou ≥130 mmHg",
        "TEMP AXILAR ≤35 ou ≥40º C",
        "FR ≤10 ou ≥25 ipm",
        "SPO2 ≤92%",
        "ALTERAÇÃO DO NÍVEL DE CONSCIÊNCIA",
        "COMPROMETIMENTO DAS VIAS AÉREAS",
        "EPISTAXE FRANCA ASSOCIADA A PELO MENOS 1 ALTERAÇÃO DE SSVV",
        "HEMATÊMESE VOLUMOSA/HEMOPTISE FRANCA",
        "MELENA / HEMATOQUEZIA COM INSTABILIDADE HEMODINÂMICA"
    ]

    # Verificar se todos os sintomas iniciais são "sim"
    todas_sim_iniciais = True
    for sintoma in sintomas_iniciais:
        resposta = input(f"{sintoma}? (sim/não): ").strip().lower()
        if resposta != "sim":
            todas_sim_iniciais = False
            break

    # Determinar a classificação com base nas respostas iniciais
    if todas_sim_iniciais:
        print("\nClassificação de Risco: COR VERMELHA")
    else:
        # Perguntas sobre os sintomas de classificação AMARELA
        sintomas_amarela = [
            "EPISTAXE COM PA < 180/110 mmHg USUÁRIO DE ANTICOAGULANTE",
            "HEMATÊMESE/MELENA COM SSVV NORMAIS",
            "HEMATOQUEZIA OU HEMOPTISE COM SSVV NORMAIS",
            "PORTADOR DE CIRROSE HEPÁTICA OU COAGULOPATIA",
            "PORTADOR DE DIABETES E/OU FAZ USO DE ANTICOAGULANTE",
            "SANGRAMENTO DE MUCOSAS (GENGIVAS, LÁBIOS)",
            "SANGRAMENTO HEMORROIDÁRIO COM DOR INTENSA (8-10/10)"
        ]

        todas_sim_amarela = True
        for sintoma in sintomas_amarela:
            resposta = input(f"{sintoma}? (sim/não): ").strip().lower()
            if resposta != "sim":
                todas_sim_amarela = False
                break

        if todas_sim_amarela:
            print("\nClassificação de Risco: COR AMARELA")
        else:
            # Perguntas sobre os sintomas de classificação VERDE
            sintomas_verde = [
                "RELATO DE HEMATÊMESE, HEMATOQUESIA",
                "RELATO DE HEMOPTISE LEVE (RAIAS DE SANGUE)",
                "RELATO DE MELENA (NORMAL NO MOMENTO)",
                "SANGRAMENTO HEMORROIDÁRIO DISCRETO E DOR LEVE/MODERADA (1-7/10)"
            ]

            todas_sim_verde = True
            for sintoma in sintomas_verde:
                resposta = input(f"{sintoma}? (sim/não): ").strip().lower()
                if resposta != "sim":
                    todas_sim_verde = False
                    break

            if todas_sim_verde:
                print("\nClassificação de Risco: COR VERDE")
            else:
                # Última pergunta para classificação AZUL
                pergunta_azul = input("ATRASO MENSTRUAL SEM OUTROS SINTOMAS? (sim/não): ").strip().lower()
                if pergunta_azul == "sim":
                    print("\nClassificação de Risco: COR AZUL")
                else:
                    print("\nClassificação não definida")


    #_________________________________________________________________

if descritivo == "10A: QUEIXAS URINÁRIAS":
    print("\nVocê escolheu QUEIXAS URINÁRIAS.")

    # Perguntas sobre os sintomas iniciais
    sintomas_iniciais = [
        "SINAIS VITAIS ALTERADOS COM SINTOMAS:",
        "FC ≤50 ou ≥120 bpm",
        "PAS ≤90 ou ≥ 220 / PAD ≤80 ou ≥130 mmHg",
        "TEMP AXILAR ≤35 ou ≥40º C",
        "FR ≤10 ou ≥25 ipm",
        "SPO2 ≤92%",
        "ALTERAÇÃO DO NÍVEL DE CONSCIÊNCIA ASSOCIADO A PELO MENOS 1 ALTERAÇÃO DE SSVV"
    ]

    # Verificar se todos os sintomas iniciais são "sim"
    todas_sim_iniciais = True
    for sintoma in sintomas_iniciais:
        resposta = input(f"{sintoma}? (sim/não): ").strip().lower()
        if resposta != "sim":
            todas_sim_iniciais = False
            break

    # Determinar a classificação com base nas respostas iniciais
    if todas_sim_iniciais:
        print("\nClassificação de Risco: COR VERMELHA")
    else:
        # Perguntas sobre os sintomas de classificação AMARELA
        sintomas_amarela = [
            "DISÚRIA INTENSA COM POLACIÚRIA E/OU HEMATÚRIA",
            "DISÚRIA COM PRESENÇA DE SECREÇÃO URETRAL E DOR SUPRAPÚBICA",
            "DOR, EDEMA E HIPEREMIA DE ESCROTO",
            "PRESENÇA DE PRIAPRISMO EM PORTADORES DE FALCEMIA",
            "INTERVENÇÕES CIRÚRGICAS RECENTES EM PRÓSTATA",
            "PROSTRAÇÃO E/OU FEBRE T > 38º C",
            "RETENÇÃO URINÁRIA AGUDA COM BEXIGOMA"
        ]

        todas_sim_amarela = True
        for sintoma in sintomas_amarela:
            resposta = input(f"{sintoma}? (sim/não): ").strip().lower()
            if resposta != "sim":
                todas_sim_amarela = False
                break

        if todas_sim_amarela:
            print("\nClassificação de Risco: COR AMARELA")
        else:
            # Perguntas sobre os sintomas de classificação VERDE
            sintomas_verde = [
                "DISÚRIA COM OU SEM RELATO DE FEBRE",
                "DIFICULDADE DE INICIAR A MICÇÃO COM DISÚRIA",
                "TRAUMA SUPERFICIAL EM GENITÁLIA EXTERNA",
                "SVD OBSTRUÍDA E/OU ASSOCIADA A QUEIXA DE DOR PÉLVICA/ABDOMINAL"
            ]

            todas_sim_verde = True
            for sintoma in sintomas_verde:
                resposta = input(f"{sintoma}? (sim/não): ").strip().lower()
                if resposta != "sim":
                    todas_sim_verde = False
                    break

            if todas_sim_verde:
                print("\nClassificação de Risco: COR VERDE")
            else:
                # Última pergunta para classificação AZUL
                pergunta_azul = input("TROCA DE SONDA VESICAL DE DEMORA (ROTINA)? (sim/não): ").strip().lower()
                if pergunta_azul == "sim":
                    print("\nClassificação de Risco: COR AZUL")
                else:
                    print("\nClassificação não definida")



#____________________________________________________________________________________
if descritivo == "11A: DOR CERVICAL/ DORSAL/ LOMBAR OU EXTREMIDADES":
    print("\nVocê escolheu DOR CERVICAL/ DORSAL/ LOMBAR OU EXTREMIDADES.")

    # Perguntas sobre os sintomas iniciais
    sintomas_iniciais = [
        "SINAIS VITAIS ALTERADOS COM SINTOMAS:",
        "FC ≤50 ou ≥120 bpm",
        "PAS ≤90 ou ≥ 220 / PAD ≤80 ou ≥130 mmHg",
        "TEMP AXILAR ≤35 ou ≥40º C",
        "FR ≤10 ou ≥25 ipm",
        "SPO2 ≤92%",
        "DOR INTENSA (8-10/10) AGUDA COM SINAIS DE ISQUEMIA OU ASSOCIADO A PELO MENOS 1 ALTERAÇÃO DE SSVV",
        "PACIENTE PORTADOR DE FALCEMIA EM CRISE ÁLGICA"
    ]

    # Verificar se todos os sintomas iniciais são "sim"
    todas_sim_iniciais = True
    for sintoma in sintomas_iniciais:
        resposta = input(f"{sintoma}? (sim/não): ").strip().lower()
        if resposta != "sim":
            todas_sim_iniciais = False
            break

    # Determinar a classificação com base nas respostas iniciais
    if todas_sim_iniciais:
        print("\nClassificação de Risco: COR VERMELHA")
    else:
        # Perguntas sobre os sintomas de classificação AMARELA
        sintomas_amarela = [
            "DOR MODERADA (4-7/10) ASSOCIADA A PELO MENOS 1 ALTERAÇÃO DE SSVV",
            "FEBRE E PRESENÇA DE SINAIS FLOGÍSTICOS LOCAIS",
            "DOR EM MMII PERSISTENTE COM EDEMA E RIGIDEZ EM PANTURRILHA",
            "LIMITAÇÃO IMPORTANTE DOS MOVIMENTOS/FUNÇÃO",
            "LOMBALGIA QUE IMPEDE DEAMBULAÇÃO OU IRRADIA PARA MMII"
        ]

        todas_sim_amarela = True
        for sintoma in sintomas_amarela:
            resposta = input(f"{sintoma}? (sim/não): ").strip().lower()
            if resposta != "sim":
                todas_sim_amarela = False
                break

        if todas_sim_amarela:
            print("\nClassificação de Risco: COR AMARELA")
        else:
            # Perguntas sobre os sintomas de classificação VERDE
            sintomas_verde = [
                "ATRALGIA COM LIMITAÇÕES SEM SINAIS FLOGÍSTICOS",
                "LIMITAÇÃO LEVE DOS MOVIMENTOS/ SEM PERDA DE FUNÇÃO",
                "DOR LEVE (1-3/10)"
            ]

            todas_sim_verde = True
            for sintoma in sintomas_verde:
                resposta = input(f"{sintoma}? (sim/não): ").strip().lower()
                if resposta != "sim":
                    todas_sim_verde = False
                    break

            if todas_sim_verde:
                print("\nClassificação de Risco: COR VERDE")
            else:
                # Última pergunta para classificação AZUL
                pergunta_azul = input("DOR CRÔNICA OU RECORRENTE? (sim/não): ").strip().lower()
                if pergunta_azul == "sim":
                    print("\nClassificação de Risco: COR AZUL")
                else:
                    print("\nClassificação não definida")


#________________________________________________________________________

if descritivo == "12A: FERIDAS E ABSCESSOS":
    print("\nVocê escolheu FERIDAS E ABSCESSOS.")

    # Perguntas sobre os sintomas iniciais
    sintomas_iniciais = [
        "SINAIS VITAIS ALTERADOS COM SINTOMAS:",
        "FC ≤50 ou ≥120 bpm",
        "PAS ≤90 ou ≥ 220 / PAD ≤80 ou ≥130 mmHg",
        "TEMP AXILAR ≤35 ou ≥40º C",
        "FR ≤10 ou ≥25 ipm",
        "SPO2 ≤92%",
        "CIANOSE/ENCHIMENTO CAPILAR > 2s",
        "ALTERAÇÃO DO NÍVEL DE CONSCIÊNCIA",
        "FERIDA COM EVISCERAÇÃO DE ÓRGÃOS",
        "FERIDA DE SANGRAMENTO NÃO COMPRESSÍVEL"
    ]

    # Verificar se todos os sintomas iniciais são "sim"
    todas_sim_iniciais = True
    for sintoma in sintomas_iniciais:
        resposta = input(f"{sintoma}? (sim/não): ").strip().lower()
        if resposta != "sim":
            todas_sim_iniciais = False
            break

    # Determinar a classificação com base nas respostas iniciais
    if todas_sim_iniciais:
        print("\nClassificação de Risco: COR VERMELHA")
    else:
        # Perguntas sobre os sintomas de classificação AMARELA
        sintomas_amarela = [
            "PRESENÇA DE TEMP AXILAR ≥ 38,5º C",
            "ABSCESSO COM FLUTUAÇÃO E/OU DOR INTENSA (8-10/10)",
            "ABSCESSO EM FACE E/OU ACOMPANHADO DE ALTERAÇÃO DE TEMPERATURA ≥ 38,5º C",
            "MIÍASE COM INFESTAÇÃO INTENSA EM FACE",
            "ACIDENTE PÉRFURO CORTANTE COM MATERIAL BIOLÓGICO",
            "FERIDA DE SANGRAMENTO COMPRESSÍVEL",
            "INFECÇÃO DE PARTES MOLES COM SINAIS FLOGÍSTICOS"
        ]

        todas_sim_amarela = True
        for sintoma in sintomas_amarela:
            resposta = input(f"{sintoma}? (sim/não): ").strip().lower()
            if resposta != "sim":
                todas_sim_amarela = False
                break

        if todas_sim_amarela:
            print("\nClassificação de Risco: COR AMARELA")
        else:
            # Perguntas sobre os sintomas de classificação VERDE
            sintomas_verde = [
                "ABSCESSO SEM FLUTUAÇÃO COM DOR LEVE-MODERADA (1-7/10)",
                "FERIDA INFECTADA SEM SINAIS SISTÊMICOS",
                "ABSCESSO/ÚLCERAS EM PACIENTES PORTADORES DE DIABETES",
                "FERIDA PEQUENA, SUPERFICIAL, SEM SANGRAMENTO OU HEMATOMA",
                "MIÍASE COM INFESTAÇÃO INTENSA",
                "SINAIS FLOGÍSTICOS EM REGIÃO GENITAL"
            ]

            todas_sim_verde = True
            for sintoma in sintomas_verde:
                resposta = input(f"{sintoma}? (sim/não): ").strip().lower()
                if resposta != "sim":
                    todas_sim_verde = False
                    break

            if todas_sim_verde:
                print("\nClassificação de Risco: COR VERDE")
            else:
                # Última pergunta para classificação AZUL
                pergunta_azul = input("CONTROLE DE ÚLCERAS CRÔNICAS EM NÃO DIABÉTICOS? (sim/não): ").strip().lower()
                if pergunta_azul == "sim":
                    print("\nClassificação de Risco: COR AZUL")
                else:
                    print("\nClassificação não definida")



#_____________________________________________________________________
if descritivo == "13A: CRISE CONVULSIVA/ ALTERAÇÕES NEUROLÓGICAS":
    print("\nVocê escolheu CRISE CONVULSIVA/ ALTERAÇÕES NEUROLÓGICAS.")

    # Perguntas sobre os sintomas iniciais
    sintomas_iniciais = [
        "SINAIS VITAIS ALTERADOS COM SINTOMAS:",
        "FC ≤50 ou ≥120 bpm",
        "PAS ≤90 ou ≥ 220 / PAD ≤80 ou ≥130 mmHg",
        "TEMP AXILAR ≤35 ou ≥40º C",
        "FR ≤10 ou ≥25 ipm",
        "SPO2 ≤92%",
        "ESCALA COMA DE GLASGOW (3 a 8)",
        "ALTERAÇÃO SÚBITA DO EQUILÍBRIO COM NÁUSEAS E VÔMITOS",
        "CONVULSÃO EM ATIVIDADE",
        "DÉFICIT AGUDO (PARESIA, PLEGIA, DISFASIA, AFASIA, PARALISIA FACIAL)",
        "EM PÓS COMICIAL, TORPOROSO E/OU COMATOSO"
    ]

    # Verificar se todos os sintomas iniciais são "sim"
    todas_sim_iniciais = True
    for sintoma in sintomas_iniciais:
        resposta = input(f"{sintoma}? (sim/não): ").strip().lower()
        if resposta != "sim":
            todas_sim_iniciais = False
            break

    # Determinar a classificação com base nas respostas iniciais
    if todas_sim_iniciais:
        print("\nClassificação de Risco: COR VERMELHA")
    else:
        # Perguntas sobre os sintomas de classificação AMARELA
        sintomas_amarela = [
            "EPILEPSIA PRÉVIA COM CRISE NAS ÚLTIMAS 24 h",
            "ESTADO PÓS COMICIAL E ALERTA",
            "PRIMEIRO EPISÓDIO DE CRISE CONVULSIVA",
            "RELATO DE DESMAIO OU SÍNCOPE COM TCE",
            "TONTEIRA ROTATÓRIA EM REPOUSO"
        ]

        todas_sim_amarela = True
        for sintoma in sintomas_amarela:
            resposta = input(f"{sintoma}? (sim/não): ").strip().lower()
            if resposta != "sim":
                todas_sim_amarela = False
                break

        if todas_sim_amarela:
            print("\nClassificação de Risco: COR AMARELA")
        else:
            # Perguntas sobre os sintomas de classificação VERDE
            sintomas_verde = [
                "CRISE CONVULSIVA > 12 h E ALERTA",
                "RELATO DE DESMAIO OU SÍNCOPE SEM TCE",
                "PARESTESIAS BILATERAIS OU MIGRATÓRIAS",
                "TONTURAS NÃO ROTATÓRIAS"
            ]

            todas_sim_verde = True
            for sintoma in sintomas_verde:
                resposta = input(f"{sintoma}? (sim/não): ").strip().lower()
                if resposta != "sim":
                    todas_sim_verde = False
                    break

            if todas_sim_verde:
                print("\nClassificação de Risco: COR VERDE")
            else:
                # Última pergunta para classificação AZUL
                pergunta_azul = input("HISTÓRIA DE CRISE CONVULSIVA/ EPILEPSIA PRECISANDO DE RECEITA MÉDICA? (sim/não): ").strip().lower()
                if pergunta_azul == "sim":
                    print("\nClassificação de Risco: COR AZUL")
                else:
                    print("\nClassificação não definida")


#___________________________________________________________________________


if descritivo == "14A: QUEIXAS RESPIRATÓRIAS":
    print("\nVocê escolheu QUEIXAS RESPIRATÓRIAS.")

    # Perguntas sobre os sintomas iniciais
    sintomas_iniciais = [
        "SINAIS VITAIS ALTERADOS COM SINTOMAS:",
        "FC ≤50 ou ≥120 bpm",
        "PAS ≤90 ou ≥ 220 / PAD ≤80 ou ≥130 mmHg",
        "TEMP AXILAR ≤35 ou ≥40º C",
        "FR ≤10 ou ≥25 ipm",
        "SPO2 ≤92%",
        "ENCHIMENTO CAPILAR > 2s / CIANOSE DE EXTREMIDADES",
        "LETARGIA E/OU CONFUSÃO MENTAL",
        "ESTRIDOR LARÍNGEO OU DIFICULDADE PARA FALAR",
        "SINAIS DE CHOQUE/ DISFUNÇÃO HEMODINÂMICA",
        "APRESENTANDO DESCONFORTO RESPIRATÓRIO E CIANOSE POR OVACE"
    ]

    # Verificar se todos os sintomas iniciais são "sim"
    todas_sim_iniciais = True
    for sintoma in sintomas_iniciais:
        resposta = input(f"{sintoma}? (sim/não): ").strip().lower()
        if resposta != "sim":
            todas_sim_iniciais = False
            break

    # Determinar a classificação com base nas respostas iniciais
    if todas_sim_iniciais and int(input("SPO2 < 95%? (sim = 1/não = 2): ")) == 1:
        print("\nClassificação de Risco: COR VERMELHA")
    else:
        # Perguntas sobre os sintomas de classificação AMARELA
        sintomas_amarela = [
            "FR ≤28 ou ≥35 ipm",
            "ESFORÇO RESPIRATÓRIO MODERADO",
            "PRESENÇA DE SIBILÂNCIA",
            "EXPCTORAÇÃO ESVERDEADA OU HEMOPTISE",
            "PRESENÇA DE FEBRE (TAX ≥38,5º/<40,9º C)"
        ]

        todas_sim_amarela = True
        for sintoma in sintomas_amarela:
            resposta = input(f"{sintoma}? (sim/não): ").strip().lower()
            if resposta != "sim":
                todas_sim_amarela = False
                break

        if todas_sim_amarela:
            print("\nClassificação de Risco: COR AMARELA")
        else:
            # Perguntas sobre os sintomas de classificação VERDE
            sintomas_verde = [
                "ESFORÇO RESPIRATÓRIO LEVE",
                "DOR TORÁCICA VENTILATÓRIA OU AO TOSSIR",
                "HISTÓRIA DE CHIEIRA NOTURNA",
                "TOSSE E CORIZA SEM FEBRE"
            ]

            todas_sim_verde = True
            for sintoma in sintomas_verde:
                resposta = input(f"{sintoma}? (sim/não): ").strip().lower()
                if resposta != "sim":
                    todas_sim_verde = False
                    break

            if todas_sim_verde:
                print("\nClassificação de Risco: COR VERDE")
            else:
                # Última pergunta para classificação AZUL
                tosse_seca = input("TOSSE SECA? (sim/não): ").strip().lower()
                if tosse_seca == "sim":
                    print("\nClassificação de Risco: COR AZUL")
                else:
                    print("\nClassificação não definida")




#__________________________________________________________________________________

if descritivo == "15A: DOR DE CABEÇA":
    print("\nVocê escolheu DOR DE CABEÇA.")

    # Perguntas sobre os sintomas iniciais
    sintomas_iniciais = [
        "SINAIS VITAIS ALTERADOS COM SINTOMAS:",
        "FC ≤50 ou ≥120 bpm",
        "PAS ≤90 ou ≥ 220 / PAD ≤80 ou ≥130 mmHg",
        "TEMP AXILAR ≤35 ou ≥40º C",
        "FR ≤10 ou ≥25 ipm",
        "SPO2 ≤92%",
        "ENCHIMENTO CAPILAR > 2s",
        "ACOMPANHADA DE RIGIDEZ DE NUCA, NÁUSEAS E VÔMITOS",
        "DOR INTENSA (8-10/10) ASSOCIADA A PELO MENOS 1 ALTERAÇÃO DE SSVV",
        "ACOMPANHADA DE DOR TORÁCICA",
        "ACOMPANHADA DE ALTERAÇÕES VISUAIS",
        "INTENSA, SÚBITA OU RAPIDAMENTE PROGRESSIVA",
        "ASSOCIADA A DÉFICIT NEUROLÓGICOS (PARESIA, PARESTESIA, DISFASIA, AFASIA, ATAXIA)"
    ]

    # Verificar se todos os sintomas iniciais são "sim"
    todas_sim_iniciais = True
    for sintoma in sintomas_iniciais:
        resposta = input(f"{sintoma}? (sim/não): ").strip().lower()
        if resposta != "sim":
            todas_sim_iniciais = False
            break

    # Determinar a classificação com base nas respostas iniciais
    if todas_sim_iniciais:
        print("\nClassificação de Risco: COR VERMELHA")
    else:
        # Perguntas sobre os sintomas de classificação AMARELA
        sintomas_amarela = [
            "DOR MODERADA (4-7/10) ACOMPANHADA NÁUSEAS E VÔMITOS OU STATUS ENXAQUECOSO DE DOR COM DURAÇÃO ≥ 72 h"
        ]

        todas_sim_amarela = True
        for sintoma in sintomas_amarela:
            resposta = input(f"{sintoma}? (sim/não): ").strip().lower()
            if resposta != "sim":
                todas_sim_amarela = False
                break

        if todas_sim_amarela:
            print("\nClassificação de Risco: COR AMARELA")
        else:
            # Perguntas sobre os sintomas de classificação VERDE
            sintomas_verde = [
                "RELATO DE FEBRE E/OU VÔMITOS",
                "DOR CRÔNICA OU RECORRENTE SEM PIORA RECENTE"
            ]

            todas_sim_verde = True
            for sintoma in sintomas_verde:
                resposta = input(f"{sintoma}? (sim/não): ").strip().lower()
                if resposta != "sim":
                    todas_sim_verde = False
                    break

            if todas_sim_verde:
                print("\nClassificação de Risco: COR VERDE")
            else:
                # Última pergunta para classificação AZUL
                print("\nClassificação de Risco: COR AZUL")


#__________________________________________________________________________________


if descritivo == "16A: ALTERAÇÕES GLICÊMICAS":
    print("\nVocê escolheu ALTERAÇÕES GLICÊMICAS.")

    # Perguntas sobre os sintomas iniciais
    sintomas_iniciais = [
        "SINAIS VITAIS ALTERADOS COM SINTOMAS:",
        "FC ≤50 ou ≥120 bpm",
        "PAS ≤90 ou ≥ 220 / PAD ≤80 ou ≥130 mmHg",
        "TEMP AXILAR ≤35 ou ≥40º C",
        "FR ≤10 ou ≥25 ipm",
        "SPO2 ≤92%",
        "GLICEMIA CAPILAR < 50 (LO) OU > 500 mg/dL (HI)",
        "ALTERAÇÃO DO NÍVEL DE CONSCIÊNCIA (LETARGIA, AGITAÇÃO, CONFUSÃO, COMA)",
        "DISPNÉIA (RÁPIDA E PROFUNDA)",
        "SUDORESE PROFUSA ASSOCIADA A PELO MENOS 1 ALTERAÇÃO DE SSVV"
    ]

    # Verificar se todos os sintomas iniciais são "sim"
    todas_sim_iniciais = True
    for sintoma in sintomas_iniciais:
        resposta = input(f"{sintoma}? (sim/não): ").strip().lower()
        if resposta != "sim":
            todas_sim_iniciais = False
            break

    # Determinar a classificação com base nas respostas iniciais
    if todas_sim_iniciais:
        print("\nClassificação de Risco: COR VERMELHA")
    else:
        # Perguntas sobre os sintomas de classificação AMARELA
        sintomas_amarela = [
            "GLICEMIA CAPILAR > 320 ou < 50 mg/dL",
            "SINAIS DE DESIDRATAÇÃO LEVE/MODERADA",
            "SPO2 ENTRE 93 e 95%"
        ]

        todas_sim_amarela = True
        for sintoma in sintomas_amarela:
            resposta = input(f"{sintoma}? (sim/não): ").strip().lower()
            if resposta != "sim":
                todas_sim_amarela = False
                break

        if todas_sim_amarela:
            print("\nClassificação de Risco: COR AMARELA")
        else:
            # Pergunta sobre os sintomas de classificação VERDE
            sintoma_verde = "GLICEMIA CAPILAR > 250 mg/dL ASSINTOMÁTICO"
            resposta_verde = input(f"{sintoma_verde}? (sim/não): ").strip().lower()

            if resposta_verde == "sim":
                print("\nClassificação de Risco: COR VERDE")
            else:
                print("\nClassificação de Risco: COR AZUL")



#____________________________________________________________

if descritivo == "17A: PRESSÃO ALTA":
    print("\nVocê escolheu PRESSÃO ALTA.")

    # Perguntas sobre os sintomas iniciais
    sintomas_iniciais = [
        "PAS > 220 ou PAD > 130 mmHg COM QUALQUER SINTOMA",
        "ALTERAÇÕES VISUAIS (VISÃO TURVA E/OU ESCOTOMAS)",
        "DOR TORÁCICA CARACTERÍSTICA DE ISQUEMIA",
        "EPISTAXE FRANCA ASSOCIADA A PAS > 220 ou PAD > 130 mmHg",
        "NÍVEL DE CONSCIÊNCIA ALTERADO (HIPOATIVO/AGITADO)",
        "SINTOMAS NEUROLÓGICOS (PARESIA, PLEGIA, AFASIA, DISFASIA, ATAXIA)"
    ]

    # Verificar se todos os sintomas iniciais são "sim"
    todas_sim_iniciais = True
    for sintoma in sintomas_iniciais:
        resposta = input(f"{sintoma}? (sim/não): ").strip().lower()
        if resposta != "sim":
            todas_sim_iniciais = False
            break

    # Determinar a classificação com base nas respostas iniciais
    if todas_sim_iniciais:
        print("\nClassificação de Risco: COR VERMELHA")
    else:
        # Perguntas sobre os sintomas de classificação AMARELA
        sintomas_amarela = [
            "PAS ENTRE 190-220 ou PAD ENTRE 120-130 mmHg COM QUALQUER SINTOMA"
        ]

        todas_sim_amarela = True
        for sintoma in sintomas_amarela:
            resposta = input(f"{sintoma}? (sim/não): ").strip().lower()
            if resposta != "sim":
                todas_sim_amarela = False
                break

        if todas_sim_amarela:
            print("\nClassificação de Risco: COR AMARELA")
        else:
            # Pergunta sobre os sintomas de classificação VERDE
            sintoma_verde = "PAD ENTRE 110-130 mmHg SEM SINTOMAS"
            resposta_verde = input(f"{sintoma_verde}? (sim/não): ").strip().lower()

            if resposta_verde == "sim":
                print("\nClassificação de Risco: COR VERDE")
            else:
                # Pergunta sobre os sintomas de classificação AZUL
                sintoma_azul = "PAS < 180 E PAD < 110 mmHg ASSINTOMÁTICO"
                resposta_azul = input(f"{sintoma_azul}? (sim/não): ").strip().lower()

                if resposta_azul == "sim":
                    print("\nClassificação de Risco: COR AZUL")
                else:
                    print("\nClassificação de Risco: Não especificada (Consulte um médico)")


#_____________________________________________________________________________________


if descritivo == "18A: QUEIXAS OCULARES":
    print("\nVocê escolheu QUEIXAS OCULARES.")

    # Perguntas sobre os sintomas iniciais
    sintomas_iniciais = [
        "FC ≤50 ou ≥120 bpm",
        "PAS ≤90 ou ≥ 220 / PAD ≤80 ou ≥130 mmHg",
        "TEMP AXILAR ≤35 ou ≥40º C",
        "FR ≤10 ou ≥25 ipm",
        "SPO2 ≤92%",
        "CONTATO DIRETO COM SUBSTÂNCIA QUÍMICA",
        "DOR INTENSA (8-10/10) E PRESENÇA DE SINTOMAS",
        "EXTRAÇÃO TRAUMÁTICA/ OBJETO CRAVADO",
        "PERDA VISUAL OU DIPLOPIA SÚBITA"
    ]

    # Verificar se todos os sintomas iniciais são "sim"
    todas_sim_iniciais = True
    for sintoma in sintomas_iniciais:
        resposta = input(f"{sintoma}? (sim/não): ").strip().lower()
        if resposta != "sim":
            todas_sim_iniciais = False
            break

    # Determinar a classificação com base nas respostas iniciais
    if todas_sim_iniciais:
        print("\nClassificação de Risco: COR VERMELHA")
    else:
        # Perguntas sobre os sintomas de classificação AMARELA
        sintomas_amarela = [
            "DOR MODERADA (4-7/10) ASSOCIADA A PELO MENOS 1 ALTERAÇÃO DE SSVV",
            "CELULITE PERIORBITÁRIA",
            "OLHO AVERMELHADO APÓS CONTATO COM SUBSTÂNCIA QUÍMICA E/OU TRAUMA"
        ]

        todas_sim_amarela = True
        for sintoma in sintomas_amarela:
            resposta = input(f"{sintoma}? (sim/não): ").strip().lower()
            if resposta != "sim":
                todas_sim_amarela = False
                break

        if todas_sim_amarela:
            print("\nClassificação de Risco: COR AMARELA")
        else:
            # Pergunta sobre os sintomas de classificação VERDE
            sintoma_verde = "DOR LEVE (1-3/10)"
            resposta_verde = input(f"{sintoma_verde}? (sim/não): ").strip().lower()

            if resposta_verde == "sim":
                print("\nClassificação de Risco: COR VERDE")
            else:
                # Pergunta sobre os sintomas de classificação AZUL
                sintoma_azul = "TERÇOL SEM CELULITE"
                resposta_azul = input(f"{sintoma_azul}? (sim/não): ").strip().lower()

                if resposta_azul == "sim":
                    print("\nClassificação de Risco: COR AZUL")
                else:
                    print("\nClassificação de Risco: Não especificada (Consulte um médico)")

#_________________________________________________________________________________



if descritivo == "19A: AFECÇÕES CUTÂNEAS/ANAFILAXIA":
    print("\nVocê escolheu AFECÇÕES CUTÂNEAS/ANAFILAXIA.")

    # Perguntas sobre os sintomas iniciais
    sintomas_iniciais = [
        "FC ≤50 ou ≥120 bpm",
        "PAS ≤90 ou ≥ 220 / PAD ≤80 ou ≥130 mmHg",
        "TEMP AXILAR ≤35 ou ≥40º C",
        "FR ≤10 ou ≥25 ipm",
        "SPO2 ≤92%",
        "ALTERAÇÃO DO NÍVEL DE CONSCIÊNCIA",
        "DIFICULDADE DE FALAR OU ESTRIDOR LARÍNGEO"
    ]

    # Verificar se todos os sintomas iniciais são "sim"
    todas_sim_iniciais = True
    for sintoma in sintomas_iniciais:
        resposta = input(f"{sintoma}? (sim/não): ").strip().lower()
        if resposta != "sim":
            todas_sim_iniciais = False
            break

    # Determinar a classificação com base nas respostas iniciais
    if todas_sim_iniciais:
        print("\nClassificação de Risco: COR VERMELHA")
    else:
        # Perguntas sobre os sintomas de classificação AMARELA
        sintomas_amarela = [
            "FEBRIL, TOXEMIADO OU PROSTRADO",
            "PRURIDO OU HIPEREMIA GENERALIZADO INTENSO",
            "QUADRO INFECCIOSO SECUNDÁRIO COM SINAIS SISTÊMICOS"
        ]

        todas_sim_amarela = True
        for sintoma in sintomas_amarela:
            resposta = input(f"{sintoma}? (sim/não): ").strip().lower()
            if resposta != "sim":
                todas_sim_amarela = False
                break

        if todas_sim_amarela:
            print("\nClassificação de Risco: COR AMARELA")
        else:
            # Pergunta sobre os sintomas de classificação VERDE
            sintoma_verde = "EXANTEMA"
            resposta_verde = input(f"{sintoma_verde}? (sim/não): ").strip().lower()

            if resposta_verde == "sim":
                print("\nClassificação de Risco: COR VERDE")
            else:
                # Pergunta sobre os sintomas de classificação AZUL
                sintoma_azul = "LESÕES TÍPICAS DE ESCABIOSE (SARNA)"
                resposta_azul = input(f"{sintoma_azul}? (sim/não): ").strip().lower()

                if resposta_azul == "sim":
                    print("\nClassificação de Risco: COR AZUL")
                else:
                    print("\nClassificação de Risco: Não especificada (Consulte um médico)")


#______________________________________________________________________________________________
if descritivo == "20A: ALTERAÇÕES DE TEMPERATURA":
    print("\nVocê escolheu ALTERAÇÕES DE TEMPERATURA.")

    # Perguntas sobre os sintomas iniciais
    sintomas_iniciais = [
        "FC ≤50 ou ≥120 bpm",
        "PAS ≤90 ou ≥ 220 / PAD ≤80 ou ≥130 mmHg",
        "TEMP AXILAR ≤35 ou ≥40º C",
        "FR ≤10 ou ≥25 ipm",
        "SPO2 ≤92%",
        "FEBRE (T. AXILAR > 38,5º C) EM IMUNO COMPROMETIDOS",
        "CEFALÉIA INTENSA OU RIGIDEZ DE NUCA",
        "FEBRE ACOMPANHADA DE VÔMITOS EM JATO",
        "PRESENÇA DE CRISE CONVULSIVA",
        "TEMP < 35º C EM VITIMAS DE AFOGAMENTO"
    ]

    # Verificar se todos os sintomas iniciais são "sim"
    todas_sim_iniciais = True
    for sintoma in sintomas_iniciais:
        resposta = input(f"{sintoma}? (sim/não): ").strip().lower()
        if resposta != "sim":
            todas_sim_iniciais = False
            break

    # Determinar a classificação com base nas respostas iniciais
    if todas_sim_iniciais:
        print("\nClassificação de Risco: COR VERMELHA")
    else:
        # Perguntas sobre os sintomas de classificação AMARELA
        sintomas_amarela = [
            "PROSTRADO OU TOXEMIADO",
            "ARTRALGIA E/OU MIALGIA MODERADA (4-7/10)",
            "CEFALÉIA E/OU DOR RETRORBITÁRIA MODERADA (4-7/10)",
            "ENJÔO E/OU RELATO DE VÔMITO"
        ]

        todas_sim_amarela = True
        for sintoma in sintomas_amarela:
            resposta = input(f"{sintoma}? (sim/não): ").strip().lower()
            if resposta != "sim":
                todas_sim_amarela = False
                break

        if todas_sim_amarela:
            print("\nClassificação de Risco: COR AMARELA")
        else:
            # Pergunta sobre os sintomas de classificação VERDE
            sintoma_verde = "FEBRE (T > 38,5º C) HÁ MAIS DE 03 DIAS"
            resposta_verde = input(f"{sintoma_verde}? (sim/não): ").strip().lower()

            if resposta_verde == "sim":
                print("\nClassificação de Risco: COR VERDE")
            else:
                # Pergunta sobre os sintomas de classificação AZUL
                sintoma_azul = "T. AXILAR < 37,5º C"
                resposta_azul = input(f"{sintoma_azul}? (sim/não): ").strip().lower()

                if resposta_azul == "sim":
                    print("\nClassificação de Risco: COR AZUL")
                else:
                    print("\nClassificação de Risco: Não especificada (Consulte um médico)")


#________________________________________________________________________________________________

# Verificar se o input é para EDEMA/ ICTERÍCIA/ FRAQUEZA/ CÂIMBRA
if descritivo == "21A: EDEMA/ ICTERÍCIA/ FRAQUEZA/ CÂIMBRA":
    print("\nVocê escolheu EDEMA/ ICTERÍCIA/ FRAQUEZA/ CÂIMBRA.")

    # Perguntas sobre os sintomas iniciais
    sintomas_iniciais = [
        "FC ≤50 ou ≥120 bpm",
        "PAS ≤90 ou ≥ 220 / PAD ≤80 ou ≥130 mmHg",
        "TEMP AXILAR ≤35 ou ≥40º C",
        "FR ≤10 ou ≥25 ipm",
        "SPO2 ≤92%",
        "ALTERAÇÃO DO NÍVEL DE CONSCIÊNCIA",
        "EDEMA GENERALIZADO (ANASARCA) ASSOCIADO À DOR E/OU DISPNEIA INTENSA"
    ]

    # Verificar se todos os sintomas iniciais são "sim"
    todas_sim_iniciais = True
    for sintoma in sintomas_iniciais:
        resposta = input(f"{sintoma}? (sim/não): ").strip().lower()
        if resposta != "sim":
            todas_sim_iniciais = False
            break

    # Determinar a classificação com base nas respostas iniciais
    if todas_sim_iniciais:
        print("\nClassificação de Risco: COR VERMELHA")
    else:
        # Perguntas sobre os sintomas de classificação AMARELA
        sintomas_amarela = [
            "EDEMA GENERALIZADO (ANASARCA)",
            "PERDA PONDERAL IMPORTANTE HÁ MENOS DE 15 DIAS"
        ]

        todas_sim_amarela = True
        for sintoma in sintomas_amarela:
            resposta = input(f"{sintoma}? (sim/não): ").strip().lower()
            if resposta != "sim":
                todas_sim_amarela = False
                break

        if todas_sim_amarela:
            print("\nClassificação de Risco: COR AMARELA")
        else:
            # Pergunta sobre os sintomas de classificação VERDE
            sintoma_verde = "FRAQUEZA OU CÂIMBRAS SEM OUTROS SINTOMAS"
            resposta_verde = input(f"{sintoma_verde}? (sim/não): ").strip().lower()

            if resposta_verde == "sim":
                print("\nClassificação de Risco: COR VERDE")
            else:
                print("\nClassificação de Risco: COR AZUL")




#_______________________________________________________________________

# Verificar se o input é para DOR DE OUVIDO E GARGANTA
if descritivo == "22A: DOR DE OUVIDO E GARGANTA":
    print("\nVocê escolheu DOR DE OUVIDO E GARGANTA.")

    # Pergunta sobre DIFICULDADE PARA DEGLUTIR E PRESENÇA DE EDEMA
    dificuldade_edema = input("Dificuldade para deglutir e presença de edema? (sim/não): ").strip().lower()

    # Perguntas sobre dor de garganta com febre T >38° C
    dor_garganta_febre = input("Dor de garganta com febre T >38° C? (sim/não): ").strip().lower()

    # Perguntas sobre dor de garganta com presença de placas e/ou toxemia
    dor_garganta_placas_toxemia = input("Dor de garganta com presença de placas e/ou toxemia? (sim/não): ").strip().lower()

    # Perguntas sobre dor de ouvido acompanhado de febre T >38° C
    dor_ouvido_febre = input("Dor de ouvido acompanhado de febre T >38° C? (sim/não): ").strip().lower()

    # Perguntas sobre dor de ouvido com presença de secreção e odor
    dor_ouvido_secrecao_odor = input("Dor de ouvido com presença de secreção e odor? (sim/não): ").strip().lower()

    # Pergunta sobre presença de corpo estranho em ouvido e/ou zumbidos
    corpo_estranho_zumbidos = input("Presença de corpo estranho em ouvido e/ou zumbidos? (sim/não): ").strip().lower()

    # Determinar a classificação com base nas respostas
    if corpo_estranho_zumbidos == "sim":
        print("\nClassificação de Risco: COR AMARELA")
    else:
        # Perguntas adicionais se nenhuma anterior foi "sim"
        ardencia_garganta = input("Ardência em garganta? (sim/não): ").strip().lower()

        if ardencia_garganta == "sim":
            print("\nClassificação de Risco: COR AMARELA")
        else:
            dor_garganta_sem_febre_24h = input("Dor de garganta sem febre < 24h? (sim/não): ").strip().lower()

            if dor_garganta_sem_febre_24h == "sim":
                print("\nClassificação de Risco: COR VERDE")
            else:
                dor_garganta_sem_febre_24h = input("Dor de garganta sem febre > 24h? (sim/não): ").strip().lower()

                if dor_garganta_sem_febre_24h == "sim":
                    print("\nClassificação de Risco: COR VERDE")
                else:
                    print("\nClassificação de Risco: COR AZUL")

#_______________________________________________________________________________

# Verificar se o input é para SITUAÇÕES DE CRISES PSÍQUICAS / ABSTINÊNCIA DE ÁLCOOL E OUTRAS DROGAS
if descritivo == "23A: SITUAÇÕES DE CRISES PSÍQUICAS / ABSTINÊNCIA DE ÁLCOOL E OUTRAS DROGAS":
    print("\nVocê escolheu SITUAÇÕES DE CRISES PSÍQUICAS / ABSTINÊNCIA DE ÁLCOOL E OUTRAS DROGAS.")

    # Perguntas sobre sinais vitais alterados com sintomas
    print("Responda sim para presença do sintoma e não para ausência do sintoma.")
    fc_alterado = input("FC ≤50 ou ≥120 bpm? (sim/não): ").strip().lower()
    pas_alterado = input("PAS ≤90 ou ≥220 / PAD ≤80 ou ≥130 mmHg? (sim/não): ").strip().lower()
    temp_alterada = input("TEMP AXILAR ≤35 ou ≥40º C? (sim/não): ").strip().lower()
    fr_alterada = input("FR ≤10 ou ≥25 ipm? (sim/não): ").strip().lower()
    spo2_alterado = input("SPO2 ≤92%? (sim/não): ").strip().lower()
    agitacao_psicomotora = input("Agitação psicomotora extrema? (sim/não): ").strip().lower()
    deficit_neurologico = input("Déficit neurológico agudo (convulsão, letargia, coma)? (sim/não): ").strip().lower()
    grave_alteracao_comportamento = input("Grave alteração de comportamento? (sim/não): ").strip().lower()
    hipertonicidade_rigidez = input("Hipertonicidade e rigidez muscular? (sim/não): ").strip().lower()
    intoxicacao_substancias = input("Intoxicação por abuso de substâncias psicoativas? (sim/não): ").strip().lower()
    quadro_depressivo_suicidio = input("Quadro depressivo grave / risco de suicídio? (sim/não): ").strip().lower()
    sindromes_abstinencia = input("Quadros de síndromes de abstinência do uso de substâncias psicoativas? (sim/não): ").strip().lower()
    risco_imediato = input("Risco imediato para si ou outrem / auto e/ou heteroagressividade? (sim/não): ").strip().lower()

    # Determinar a classificação com base nas respostas
    if risco_imediato == "sim":
        print("\nClassificação de Risco: COR VERMELHA")
    else:
        # Perguntas adicionais se nenhuma anterior foi "sim"
        agitacao_psicomotora_menor = input("Agitação psicomotora de menor intensidade associado a pelo menos 1 alteração de SSVV? (sim/não): ").strip().lower()

        if agitacao_psicomotora_menor == "sim":
            print("\nClassificação de Risco: COR AMARELA")
        else:
            alucinacao_desorientacao = input("Alucinação, desorientação associado a pelo menos 1 alteração de SSVV? (sim/não): ").strip().lower()

            if alucinacao_desorientacao == "sim":
                print("\nClassificação de Risco: COR AMARELA")
            else:
                estado_panico = input("Estado de pânico? (sim/não): ").strip().lower()

                if estado_panico == "sim":
                    print("\nClassificação de Risco: COR AMARELA")
                else:
                    ideia_suicida = input("Ideia suicida? (sim/não): ").strip().lower()

                    if ideia_suicida == "sim":
                        print("\nClassificação de Risco: COR AMARELA")
                    else:
                        ansiedade_moderada = input("Ansiedade moderada? (sim/não): ").strip().lower()

                        if ansiedade_moderada == "sim":
                            print("\nClassificação de Risco: COR VERDE")
                        else:
                            historia_transtorno_mental = input("História de transtorno mental? (sim/não): ").strip().lower()

                            if historia_transtorno_mental == "sim":
                                print("\nClassificação de Risco: COR VERDE")
                            else:
                                humor_depressivo = input("Humor deprimido? (sim/não): ").strip().lower()

                                if humor_depressivo == "sim":
                                    print("\nClassificação de Risco: COR VERDE")
                                else:
                                    inquietacao = input("Inquietação, mas não agitado? (sim/não): ").strip().lower()

                                    if inquietacao == "sim":
                                        print("\nClassificação de Risco: COR VERDE")
                                    else:
                                        # Perguntas específicas para a classificação AZUL
                                        crise_problemas_sociais = input("Crise ou problemas sociais? (sim/não): ").strip().lower()
                                        depressao_cronica = input("Depressão crônica ou recorrente? (sim/não): ").strip().lower()
                                        historico_disturbio_psiquiatrico = input("Histórico de distúrbio psiquiátrico precisando de receita médica? (sim/não): ").strip().lower()
                                        insonia_impulsividade = input("Insônia ou impulsividade? (sim/não): ").strip().lower()

                                        if (crise_problemas_sociais == "sim" or depressao_cronica == "sim" or historico_disturbio_psiquiatrico == "sim" or insonia_impulsividade == "sim"):
                                            print("\nClassificação de Risco: COR AZUL")
                                        else:
                                            print("\nClassificação de Risco: COR VERDE")


#__________________________________________________________________

# Verificar se o input é para SITUAÇÕES DE BAIXA COMPLEXIDADE
if descritivo == "24A: SITUAÇÕES DE BAIXA COMPLEXIDADE":
    print("\nVocê escolheu SITUAÇÕES DE BAIXA COMPLEXIDADE.")

    # Perguntas específicas para este cenário
    imunizacoes = input("Imunizações ou atualização do cartão de vacina? (sim/não): ").strip().lower()
    questoes_sociais = input("Questões sociais sem acometimento clínico? (sim/não): ").strip().lower()
    retirada_corpo_estranho = input("Retirada de corpo estranho em região perineal? (sim/não): ").strip().lower()
    retirada_pontos = input("Retirada de pontos? (sim/não): ").strip().lower()
    exames_complementares = input("Realização ou avaliação de exames complementares não urgente? (sim/não): ").strip().lower()
    atestados_medicos = input("Solicitações de atestados médicos? (sim/não): ").strip().lower()
    teste_gravidez = input("Solicitação de teste de gravidez? (sim/não): ").strip().lower()
    irregularidade_menstrual = input("Irregularidade menstrual sem alteração de dados vitais? (sim/não): ").strip().lower()
    problemas_contraceptivos = input("Problemas ou dúvidas relacionados ao uso de contraceptivos? (sim/não): ").strip().lower()
    troca_curativo = input("Troca de curativo? (sim/não): ").strip().lower()
    requisicao_receita_medica = input("Trocas ou requisições de receita médica? (sim/não): ").strip().lower()
    dor_pelvica_cronica = input("Dor pélvica crônica ou recorrente? (sim/não): ").strip().lower()

    # Determinar a classificação com base nas respostas
    if (imunizacoes == "sim" or questoes_sociais == "sim" or retirada_corpo_estranho == "sim" or retirada_pontos == "sim" or
        exames_complementares == "sim" or atestados_medicos == "sim" or teste_gravidez == "sim" or
        irregularidade_menstrual == "sim" or problemas_contraceptivos == "sim" or troca_curativo == "sim" or
        requisicao_receita_medica == "sim" or dor_pelvica_cronica == "sim"):
        print("\nClassificação de Risco: COR AZUL")
    else:
        print("\nClassificação de Risco: COR VERDE")


#_______________________________________________________


# Verificar se o input é para PARADA CÁRDIORESPIRATÓRIA (PCR)
if descritivo == "1B: PARADA CÁRDIORESPIRATÓRIA (PCR)":
    print("\nVocê escolheu PARADA CÁRDIORESPIRATÓRIA (PCR).")

    # Perguntas específicas para este cenário
    crianca_sem_dados_vitais = input("Criança atendida sem dados vitais? (sim/não): ").strip().lower()
    inconsciente_sem_respirar = input("Inconsciente e sem respirar? (sim/não): ").strip().lower()
    ausencia_pulso_central = input("Ausência de pulso central? (sim/não): ").strip().lower()
    fc_hipoperfusao = input("Com FC ≤ 60 bpm e sinais de hipoperfusão tecidual? (sim/não): ").strip().lower()
    cianose_central = input("Cianose central? (sim/não): ").strip().lower()
    respiracao_irregular = input("Com respiração irregular (acima de 01 ano > 50 ipm / abaixo de 01 ano > 60 ipm)? (sim/não): ").strip().lower()

    # Determinar a classificação com base nas respostas
    if (crianca_sem_dados_vitais == "sim" or inconsciente_sem_respirar == "sim" or ausencia_pulso_central == "sim" or
        (fc_hipoperfusao == "sim" and respiracao_irregular == "sim") or cianose_central == "sim"):
        print("\nClassificação de Risco: COR VERMELHA")
    else:
        print("\nClassificação de Risco: OUTRO")


#__________________________________________________________


# Verificar se o input é para DESEQUILÍBRIO HEMODINÂMICO
if descritivo == "2B: DESEQUILÍBRIO HEMODINÂMICO":
    print("\nVocê escolheu DESEQUILÍBRIO HEMODINÂMICO.")

    # Perguntas específicas para este cenário
    sinais_vitais_criticos = input("Sinais vitais (FC, FR, SAT O2, T, PA) em níveis críticos? (sim/não): ").strip().lower()
    alteracao_estado_mental = input("Alteração do estado mental: agitação ou sonolência? (sim/não): ").strip().lower()
    fc_critica = input("Frequência cardíaca < 50 bpm ou ≥ 160 bpm (para maiores de 2 anos) ou ≥ 180 bpm (para menores de 2 anos)? (sim/não): ").strip().lower()
    sudorese_pele_fria_umida_palidez = input("Sudorese, pele fria e úmida, palidez acentuada? (sim/não): ").strip().lower()

    # Determinar a classificação com base nas respostas
    if (sinais_vitais_criticos == "sim" or alteracao_estado_mental == "sim" or fc_critica == "sim" or sudorese_pele_fria_umida_palidez == "sim"):
        print("\nClassificação de Risco: COR VERMELHA")
    else:
        print("\nClassificação de Risco: OUTRO")

#__________________________________________________________________
# Verificar se o input é para QUEIXAS RESPIRATÓRIAS
if descritivo == "4B: QUEIXAS RESPIRATÓRIAS":
    print("\nVocê escolheu QUEIXAS RESPIRATÓRIAS.")

    # Perguntas específicas para este cenário
    sinais_vitais_criticos = input("Sinais vitais (FC, FR, SPO2, T, PA) em níveis críticos? (sim/não): ").strip().lower()
    cianose_central_extremidades = input("Cianose central ou extremidades arroxeadas? (sim/não): ").strip().lower()
    confusao_mental_sonolencia = input("Confusão mental ou sonolência? (sim/não): ").strip().lower()
    fc_maior_160_maior_2_anos = input("Frequência cardíaca ≥ 160 bpm para maiores de 2 anos? (sim/não): ").strip().lower()
    fc_maior_180_menor_2_anos = input("Frequência cardíaca ≥ 180 bpm para menores de 2 anos? (sim/não): ").strip().lower()

    # Determinar a classificação com base nas respostas
    if (sinais_vitais_criticos == "sim" or
        cianose_central_extremidades == "sim" or
        confusao_mental_sonolencia == "sim" or
        fc_maior_160_maior_2_anos == "sim" or
        fc_maior_180_menor_2_anos == "sim"):
        print("\nClassificação de Risco: COR VERMELHA")
    else:
        sinais_vitais_alterados = input("Sinais vitais (FC, FR, SPO2, PA) alterados sem níveis críticos? (sim/não): ").strip().lower()
        irritabilidade_excessiva_sonolencia_leve = input("Irritabilidade excessiva ou sonolência leve? (sim/não): ").strip().lower()
        dificuldade_respiratoria_mod = input("Moderada dificuldade respiratória (tiragem intercostal, batimentos em asa de nariz, retração de fúrcula esternal, respiração subdiafragmática)? (sim/não): ").strip().lower()
        ronqueira_chiado_audiveis = input("Presença de ronqueira ou chiado audíveis? (sim/não): ").strip().lower()
        palidez_sem_cianose = input("Palidez sem cianose? (sim/não): ").strip().lower()
        febre_38 = input("Febre ≥ 38ºC? (sim/não): ").strip().lower()

        # Determinar a classificação com base nas respostas adicionais
        if (sinais_vitais_alterados == "sim" or
            irritabilidade_excessiva_sonolencia_leve == "sim" or
            dificuldade_respiratoria_mod == "sim" or
            ronqueira_chiado_audiveis == "sim" or
            palidez_sem_cianose == "sim" or
            febre_38 == "sim"):
            print("\nClassificação de Risco: COR AMARELA")
        else:
            historia_dispneia_melhorou_24h = input("História de dispneia que já melhorou há 24h e sem nenhum sinal dos quadros anteriores? (sim/não): ").strip().lower()
            fr_dificuldade_falar = input("Frequência respiratória ≤ 15 ipm ou ≥ 60 ipm com dificuldade de falar? (sim/não): ").strip().lower()

            if historia_dispneia_melhorou_24h == "sim" and fr_dificuldade_falar == "não":
                print("\nClassificação de Risco: COR AZUL")
            else:
                print("\nClassificação de Risco: COR VERDE")
#____________________________________________________________

#3B: ALTERAÇÃO DO NÍVEL DE CONSCIÊNCIA AFOGAMENTO
#5B: ALTERAÇÕES DA TEMPERATURA
#6B: DOR DE OUVIDO E GARGANTA
#7B: FERIDAS E ABSCESSOS
#8B: SINAIS DE DESIDRATAÇÃO/VÔMITOS
#9B: DEJEÇÕES DIARREICAS
#10B: QUEIXAS ABDOMINAIS
#11B: TRAUMA DE CRÂNIO
#12B: TRAUMA GERAL
#13B: QUEIMADURAS
#14B: MORDEDURA DE ANIMAL / ACIDENTE COM ANIMAL PEÇONHENTO
#15B: INTOXICAÇÃO AGUDA/ ENVENENAMENTO
#16B: CRIANÇAS MENORES DE 02 MESES
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>1A</th>
#       <th>1B</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1A: PARADA CÁRDIORESPIRATÓRIA (PCR)</td>
#       <td>1B: PARADA CÁRDIORESPIRATÓRIA (PCR)</td>
#     </tr>
#     <tr>
#       <td>2A: QUEIMADURAS</td>
#       <td>2B: DESEQUILÍBRIO HEMODINÂMICO</td>
#     </tr>
#     <tr>
#       <td>3A: TRAUMA DE CRÂNIO</td>
#       <td>3B: ALTERAÇÃO DO NÍVEL DE CONSCIÊNCIA AFOGAMENTO</td>
#     </tr>
#     <tr>
#       <td>4A: QUEIXAS ABDOMINAIS</td>
#       <td>4B: QUEIXAS RESPIRATÓRIAS</td>
#     </tr>
#     <tr>
#       <td>5A: TRAUMA GERAL</td>
#       <td>5B: ALTERAÇÕES DA TEMPERATURA</td>
#     </tr>
#     <tr>
#       <td>6A: MORDEDURA DE ANIMAL / ACIDENTE COM ANIMAL PEÇONHENTO</td>
#       <td>6B: DOR DE OUVIDO E GARGANTA</td>
#     </tr>
#     <tr>
#       <td>7A: INTOXICAÇÃO AGUDA / ENVENENAMENTO</td>
#       <td>7B: FERIDAS E ABSCESSOS</td>
#     </tr>
# ...
